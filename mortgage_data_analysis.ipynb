# %%
import pandas as pd
import numpy as np

# %%
# Importingt the CSV into a dataframe to use and analyze
df = pd.read_csv("mortgage_data.csv")

# %%
df.head(10)
# Out:
#     loan_id  borrower_income  loan_amount  interest_rate  loan_term  \
# 0  LN000001         94934.28    404951.66           3.74         20
# 1  LN000002         82234.71    369347.53           4.14         20
# 2  LN000003         97953.77    304472.28           3.66         20
# 3  LN000004        115460.60    251479.74           4.02         15
# 4  LN000005         80316.93    352366.75           2.83         30
# 5  LN000006         80317.26    329511.40           4.41         30
# 6  LN000007        116584.26    367139.49           4.25         20
# 7  LN000008        100348.69    347637.89           3.64         15
# 8  LN000009         75610.51    378716.45           4.74         30
# 9  LN000010         95851.20    259857.36           4.95         20
#
#    credit_score  property_value  ltv_ratio  dti_ratio loan_status  \
# 0           597       530249.24      76.37      20.50     Current
# 1           640       458707.09      80.52      31.84     Current
# ...
